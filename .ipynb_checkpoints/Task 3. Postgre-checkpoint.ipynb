# %% [markdown]
# # Работа с демонстрационной БД  «Авиаперевозки» в PostGre
#
# Вам предоставляется демонстрационная БД, развернутая в СУБД PostGre.
# Режим доступа - только на чтение.

# %%
import os
import json
import psycopg2
from psycopg2.extras import DictCursor

# %%
POSTGRESQL_HOST = '10.129.0.25'

# %%
# !env | grep POST
# Out:
# POSTGRESQL_USER=reader
# POSTGRESQL_PASSWORD=Miba2021

# %% [markdown]
# Создание подключения к БД

# %%
conn = psycopg2.connect(
    dbname='demo', 
    user=os.environ['POSTGRESQL_USER'],
    password=os.environ['POSTGRESQL_PASSWORD'], 
    host=POSTGRESQL_HOST
)
cur = conn.cursor()

# %% [markdown]
# Получение параметров подключения (в будущем вам это пригодится)

# %%
conn.get_dsn_parameters()
# Out:
# {'user': 'reader',
#  'channel_binding': 'prefer',
#  'dbname': 'demo',
#  'host': '10.129.0.25',
#  'port': '5432',
#  'options': '',
#  'sslmode': 'prefer',
#  'sslcompression': '0',
#  'sslcertmode': 'allow',
#  'sslsni': '1',
#  'ssl_min_protocol_version': 'TLSv1.2',
#  'gssencmode': 'prefer',
#  'krbsrvname': 'postgres',
#  'gssdelegation': '0',
#  'target_session_attrs': 'any',
#  'load_balance_hosts': 'disable'}

# %% [markdown]
# Подготовка SQL запроса на вывод первых 5 записей из таблицы seats

# %%
query = 'SELECT * FROM seats LIMIT 5'

# %%
cur.execute(query)
records = cur.fetchall()
cur.close()
conn.close()

# %%
records
# Out:
# [('319', '2A', 'Business'),
#  ('319', '2C', 'Business'),
#  ('319', '2D', 'Business'),
#  ('319', '2F', 'Business'),
#  ('319', '3A', 'Business')]

# %% [markdown]
# Через конструкцию  with as реализуем соединение с БД и выполним SQL запрос

# %%
with psycopg2.connect(
    dbname='demo', 
    user=os.environ['POSTGRESQL_USER'],
    password=os.environ['POSTGRESQL_PASSWORD'], 
    host=POSTGRESQL_HOST
) as conn:
    with conn.cursor() as cur:
        cur.execute('SELECT * FROM seats LIMIT 10')
        records = cur.fetchall()

# %%
records
# Out:
# [('319', '2A', 'Business'),
#  ('319', '2C', 'Business'),
#  ('319', '2D', 'Business'),
#  ('319', '2F', 'Business'),
#  ('319', '3A', 'Business'),
#  ('319', '3C', 'Business'),
#  ('319', '3D', 'Business'),
#  ('319', '3F', 'Business'),
#  ('319', '4A', 'Business'),
#  ('319', '4C', 'Business')]

# %% [markdown]
# Подготовим словарь с тремя запросам  на получение информации о БД

# %%
queries = {
    '___DATABASES___': 'SELECT * FROM pg_database',
    '___TABLES___': "SELECT relname FROM pg_class WHERE relkind='r' AND relname !~ '^(pg_|sql_)';",
    '\n___COLUMNS___': "SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'seats';"
}

# %%
with psycopg2.connect(
    dbname='demo', 
    user=os.environ['POSTGRESQL_USER'],
    password=os.environ['POSTGRESQL_PASSWORD'], 
    host=POSTGRESQL_HOST
) as conn:
    for name, query in queries.items():
        print('\n', name)
        with conn.cursor() as cur:
            cur.execute(query)
            for row in cur.fetchall():
                print(row)
# Out:
#  ___DATABASES___
# (13760, 'postgres', 10, 6, 'en_US.UTF-8', 'en_US.UTF-8', False, True, -1, 13759, '726', '1', 1663, None)
# (1, 'template1', 10, 6, 'en_US.UTF-8', 'en_US.UTF-8', True, True, -1, 13759, '726', '1', 1663, '{=c/postgres,postgres=CTc/postgres}')
# (13759, 'template0', 10, 6, 'en_US.UTF-8', 'en_US.UTF-8', True, False, -1, 13759, '726', '1', 1663, '{=c/postgres,postgres=CTc/postgres}')
# (16384, 'demo', 10, 6, 'en_US.UTF-8', 'en_US.UTF-8', False, True, -1, 13759, '726', '1', 1663, '{=Tc/postgres,postgres=CTc/postgres,reader=c/postgres}')
#
#  ___TABLES___
# ('boarding_passes',)
# ('aircrafts_data',)
# ('flights',)
# ('airports_data',)
# ('seats',)
# ('tickets',)
# ('ticket_flights',)
# ('bookings',)
# ('employees',)
# ('departments',)
# ('department',)
# ('employee',)
#
#
# ___COLUMNS___
# ('aircraft_code',)
# ('seat_no',)
# ('fare_conditions',)

# %%
tables_db = []
query = "SELECT relname FROM pg_class WHERE relkind='r' AND relname !~ '^(pg_|sql_)';"
with psycopg2.connect(
    dbname='demo', 
    user=os.environ['POSTGRESQL_USER'],
    password=os.environ['POSTGRESQL_PASSWORD'], 
    host=POSTGRESQL_HOST
) as conn:
    with conn.cursor() as cur:
        cur.execute(query)
        for row in cur.fetchall():
            tables_db.append(row[0])

# %%
print(tables_db)
# Out:
# ['boarding_passes', 'aircrafts_data', 'flights', 'airports_data', 'seats', 'tickets', 'ticket_flights', 'bookings', 'employees', 'departments', 'department', 'employee']

# %% [markdown]
# ## Задание 1:
# Для каждой таблицы БД выведите ее структуру (название колонок).
#
# В текстовой ячейке представьте описание каждой таблицы - ее назначение и структуру.

# %% [markdown]
# Пример использования магической команды sql

# %%
# %load_ext sql

# %%
CONNECT_DATA = 'postgresql://{}:{}@{}/{}'.format(
    os.environ['POSTGRESQL_USER'],
    os.environ['POSTGRESQL_PASSWORD'],
    POSTGRESQL_HOST,
    'demo'
)

# %%
for table in tables_db:
    print(table)
    query = f"SELECT column_name, udt_name FROM information_schema.columns WHERE table_name = '{table}'"
    with conn.cursor() as cur:
        cur.execute(query)
        for row in cur.fetchall():
            print(row)
    print()
# Out:
# boarding_passes
# ('flight_id', 'int4')
# ('boarding_no', 'int4')
# ('ticket_no', 'bpchar')
# ('seat_no', 'varchar')
#
# aircrafts_data
# ('model', 'jsonb')
# ('range', 'int4')
# ('aircraft_code', 'bpchar')
#
# flights
# ('flight_id', 'int4')
# ('scheduled_departure', 'timestamptz')
# ('scheduled_arrival', 'timestamptz')
# ('actual_departure', 'timestamptz')
# ('actual_arrival', 'timestamptz')
# ('arrival_airport', 'bpchar')
# ('flight_no', 'bpchar')
# ('status', 'varchar')
# ('aircraft_code', 'bpchar')
# ('departure_airport', 'bpchar')
#
# airports_data
# ('airport_name', 'jsonb')
# ('city', 'jsonb')
# ('coordinates', 'point')
# ('airport_code', 'bpchar')
# ('timezone', 'text')
#
# seats
# ('aircraft_code', 'bpchar')
# ('seat_no', 'varchar')
# ('fare_conditions', 'varchar')
#
# tickets
# ('contact_data', 'jsonb')
# ('ticket_no', 'bpchar')
# ('book_ref', 'bpchar')
# ('passenger_id', 'varchar')
# ('passenger_name', 'text')
#
# ticket_flights
# ('flight_id', 'int4')
# ('amount', 'numeric')
# ('ticket_no', 'bpchar')
# ('fare_conditions', 'varchar')
#
# bookings
# ('book_date', 'timestamptz')
# ('total_amount', 'numeric')
# ('book_ref', 'bpchar')
#
# employees
# ('hire_date', 'date')
# ('employee_id', 'int4')
# ('manager_id', 'int4')
# ('department_id', 'int4')
# ('first_name', 'varchar')
# ('last_name', 'varchar')
# ('job_id', 'varchar')
#
# departments
# ('department_id', 'int4')
# ('manager_id', 'int4')
# ('department_name', 'varchar')
#
# department
# ('department_id', 'int4')
# ('manager_id', 'int4')
# ('department_name', 'varchar')
#
# employee
# ('hire_date', 'date')
# ('employee_id', 'int4')
# ('manager_id', 'int4')
# ('department_id', 'int4')
# ('first_name', 'varchar')
# ('last_name', 'varchar')
# ('job_id', 'varchar')

# %% [markdown]
# Получим информацию по типу каждого столбца таблицы boarding_passes

# %%
# %%sql $CONNECT_DATA
# SELECT column_name, udt_name
# FROM information_schema.columns
# WHERE table_name = 'boarding_passes'
# Out:
# 4 rows affected.
# [('flight_id', 'int4'),
#  ('boarding_no', 'int4'),
#  ('ticket_no', 'bpchar'),
#  ('seat_no', 'varchar')]

# %% [markdown]
# ## Задание 2:
# Для каждой таблицы выведите информацию о типах ее столбцов (полей) и количестве записей.
#
# Создайте словарь с названием таблиц и количеством записей в них.
#
# Найти и вывести название таблицы с максимальным количеством записей, количество записей также вывести.

# %%
def cursor (query, conn):
    with conn.cursor() as cur:
        cur.execute(query)
        return cur.fetchall()

# %%
table_dict = {}
for table in tables_db:
    print('Name of table: ', table)
    query_udt = f"SELECT column_name, udt_name FROM information_schema.columns WHERE table_name = '{table}'"
    query_count = f'SELECT COUNT(*) FROM {table}'
    count = cursor(query_count, conn)
    udt = cursor(query_udt, conn)
    print('Count: ', count[0][0], '\n')
    table_dict[table] = count[0][0]
    for cow in udt:
        print(cow[0], cow[1])
    print('\n', '\n')
        # print(udt)
# Out:
# Name of table:  boarding_passes
# Count:  7925812
#
# flight_id int4
# boarding_no int4
# ticket_no bpchar
# seat_no varchar
#
#
#
# Name of table:  aircrafts_data
# Count:  9
#
# model jsonb
# range int4
# aircraft_code bpchar
#
#
#
# Name of table:  flights
# Count:  214867
#
# flight_id int4
# scheduled_departure timestamptz
# scheduled_arrival timestamptz
# actual_departure timestamptz
# actual_arrival timestamptz
# arrival_airport bpchar
# flight_no bpchar
# status varchar
# aircraft_code bpchar
# departure_airport bpchar
#
#
#
# Name of table:  airports_data
# Count:  104
#
# airport_name jsonb
# city jsonb
# coordinates point
# airport_code bpchar
# timezone text
#
#
#
# Name of table:  seats
# Count:  1339
#
# aircraft_code bpchar
# seat_no varchar
# fare_conditions varchar
#
#
#
# Name of table:  tickets
# Count:  2949857
#
# contact_data jsonb
# ticket_no bpchar
# book_ref bpchar
# passenger_id varchar
# passenger_name text
#
#
#
# Name of table:  ticket_flights
# Count:  8391852
#
# flight_id int4
# amount numeric
# ticket_no bpchar
# fare_conditions varchar
#
#
#
# Name of table:  bookings
# Count:  2111110
#
# book_date timestamptz
# total_amount numeric
# book_ref bpchar
#
#
#
# Name of table:  employees
# Count:  12
#
# hire_date date
# employee_id int4
# manager_id int4
# department_id int4
# first_name varchar
# last_name varchar
# job_id varchar
#
#
#
# Name of table:  departments
# Count:  10
#
# department_id int4
# manager_id int4
# department_name varchar
#
#
#
# Name of table:  department
# Count:  10
#
# department_id int4
# manager_id int4
# department_name varchar
#
#
#
# Name of table:  employee
# Count:  12
#
# hire_date date
# employee_id int4
# manager_id int4
# department_id int4
# first_name varchar
# last_name varchar
# job_id varchar

# %%
max_table = max(table_dict, key=table_dict.get)
print("Table with max count: ", max_table, '\nCount: ', table_dict[max_table])
# Out:
# Table with max count:  ticket_flights
# Count:  8391852

# %% [markdown]
# ## Задание 3:
#
# Вывести названия тарифов, которые предлагают авиаперевозчики пассажирам.

# %%
query = 'SELECT DISTINCT fare_conditions FROM ticket_flights'
cursor (query, conn)
# Out:
# [('Business',), ('Comfort',), ('Economy',)]

# %% [markdown]
# ## Задание 4:
#
# По каждому тарифу найти общую сумму выручки за продажу билетов.

# %%
query = 'SELECT fare_conditions, SUM(amount) As total_amount FROM ticket_flights GROUP BY fare_conditions'
cursor(query, conn)
# Out:
# [('Business', Decimal('44321628100.00')),
#  ('Comfort', Decimal('4580291100.00')),
#  ('Economy', Decimal('118507139900.00'))]

# %% [markdown]
# ## Задание 5:
#
# Какой тариф приносит максимальный доход? (написать SQL запрос)

# %%
q = 'select * from aircrafts_data'
cursor(q, conn)
# Out:
# [('773', {'en': 'Boeing 777-300', 'ru': 'Боинг 777-300'}, 11100),
#  ('763', {'en': 'Boeing 767-300', 'ru': 'Боинг 767-300'}, 7900),
#  ('SU9', {'en': 'Sukhoi Superjet-100', 'ru': 'Сухой Суперджет-100'}, 3000),
#  ('320', {'en': 'Airbus A320-200', 'ru': 'Аэробус A320-200'}, 5700),
#  ('321', {'en': 'Airbus A321-200', 'ru': 'Аэробус A321-200'}, 5600),
#  ('319', {'en': 'Airbus A319-100', 'ru': 'Аэробус A319-100'}, 6700),
#  ('733', {'en': 'Boeing 737-300', 'ru': 'Боинг 737-300'}, 4200),
#  ('CN1', {'en': 'Cessna 208 Caravan', 'ru': 'Сессна 208 Караван'}, 1200),
#  ('CR2', {'en': 'Bombardier CRJ-200', 'ru': 'Бомбардье CRJ-200'}, 2700)]

# %%
query = 'SELECT model, MIN(range) As min_range FROM aircrafts_data GROUP BY model ORDER BY min_range LIMIT 1'
cursor(query, conn)[0][0]
# Out:
# {'en': 'Cessna 208 Caravan', 'ru': 'Сессна 208 Караван'}

# %% [markdown]
# # Время выполнения запросов.
#
# Разные запросы требуют разное время на выполнение. Часто нужно оптимизировать запрос, либо находить и использовать другой инструмент для анализа данных.
#
# Приведем пример подчета времени выполнения запроса.

# %%
# %time 
result =  %sql SELECT * from departments;
# Out:
# CPU times: user 2 μs, sys: 0 ns, total: 2 μs
# Wall time: 5.96 μs
#  * postgresql://reader:***@10.129.0.25/demo
# 10 rows affected.

# %%
result
# Out:
# [(10, 'Administration', 200),
#  (30, 'Purchasing', 114),
#  (40, 'HumanResources', 203),
#  (50, 'Shipping', 121),
#  (60, 'IT', 103),
#  (70, 'PublicRelations', 204),
#  (80, 'Sales', 145),
#  (90, 'Executive', 100),
#  (100, 'Finance', 108),
#  (110, 'Accounting', 205)]

# %% [markdown]
# ## Задание 5:
# Реализуйте 2 способами поиск модели самолета, у которого среди всех моделей минимальное значение максимальной дальности полета.
#
# Выведите время выполнения первого запроса и второго запроса, оцените какой запрос быстрее выполняется, объясните - почему?

# %%
query = 'SELECT model, SUM(amount) As max_range FROM ticket_flights GROUP BY fare_conditions ORDER BY total_amount DESC LIMIT 1;'

# %%
# %%time  
result = %sql SELECT model, MAX(range) As max_range FROM aircrafts_data GROUP BY model ORDER BY max_range LIMIT 1;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 1 rows affected.
# CPU times: user 0 ns, sys: 1.82 ms, total: 1.82 ms
# Wall time: 2.8 ms

# %%
result
# Out:
# [({'en': 'Cessna 208 Caravan', 'ru': 'Сессна 208 Караван'}, 1200)]

# %%
# %%time
result = %sql SELECT model, range FROM aircrafts_data WHERE range = (SELECT MIN(range) FROM aircrafts_data);
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 1 rows affected.
# CPU times: user 1.31 ms, sys: 255 μs, total: 1.57 ms
# Wall time: 2.24 ms

# %%
result
# Out:
# [({'en': 'Cessna 208 Caravan', 'ru': 'Сессна 208 Караван'}, 1200)]

# %% [markdown]
# ## Задание 6:
#
# Выведите сколько всего рейсов в БД имеют максимальную длительность полета.
#
# Какова максимальная длительность полета?

# %%
# %%sql
# WITH max_duration AS (
#     SELECT MAX(AGE(scheduled_arrival, scheduled_departure)) AS max_duration
#     FROM flights
# )
# SELECT
#     max_duration.max_duration,
#     COUNT(*) AS flights_with_max_duration
# FROM
#     flights, max_duration
# WHERE
#     AGE(flights.scheduled_arrival, flights.scheduled_departure) = max_duration.max_duration
# GROUP BY
#     max_duration.max_duration;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 1 rows affected.
# [(datetime.timedelta(seconds=31800), 1132)]

# %% [markdown]
# ## Задание 7:
# Выведите уникальные маршруты рейсов (по аэропортам отправления и прибытия) с максимальной длительностью полета, включая следующие данные:
# - Код и название аэропорта отправления.
# - Город отправления.
# - Код и название аэропорта прибытия.
# - Город прибытия.
# - Длительность рейса (максимальная среди всех рейсов для данного маршрута).
#
#
# Например:
# | Duration   | Departure Airport Name         | Departure City  | Arrival Airport Name          | Arrival City          |
# |------------|--------------------------------|-----------------|-------------------------------|-----------------------|
# | 10:15:00   | John F. Kennedy Airport       | New York        | Los Angeles International     | Los Angeles          |
# | 10:15:00    | Heathrow Airport              | London          | Dubai International Airport   | Dubai                |
# | 10:15:00    | Tokyo Haneda Airport          | Tokyo           | Sydney Kingsford Smith        | Sydney               |
# | 10:15:00    | Frankfurt Airport             | Frankfurt       | Changi Airport                | Singapore            |

# %%
# %%sql
# WITH flight_durations AS (
#     SELECT
#         departure_airport,
#         arrival_airport,
#         MAX(AGE(scheduled_arrival, scheduled_departure)) AS max_duration
#     FROM flights
#     GROUP BY departure_airport, arrival_airport
# )
# SELECT
#     fd.max_duration,
#     dep.airport_code AS departure_code,
#     dep.airport_name->>'en' AS departure_name,
#     dep.city->>'en' AS departure_city,
#     arr.airport_code AS arrival_code,
#     arr.airport_name->>'en' AS arrival_name,
#     arr.city->>'en' AS arrival_city
# FROM
#     flight_durations fd
# JOIN airports_data dep ON fd.departure_airport = dep.airport_code
# JOIN airports_data arr ON fd.arrival_airport = arr.airport_code
# ORDER BY fd.max_duration DESC;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 618 rows affected.
# [(datetime.timedelta(seconds=31800), 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=31800), 'DME', 'Domodedovo International Airport', 'Moscow', 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk'),
#  (datetime.timedelta(seconds=31800), 'PKC', 'Yelizovo Airport', 'Petropavlovsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=31800), 'DME', 'Domodedovo International Airport', 'Moscow', 'PKC', 'Yelizovo Airport', 'Petropavlovsk'),
#  (datetime.timedelta(seconds=31500), 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=31500), 'GDX', 'Sokol Airport', 'Magadan', 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody'),
#  (datetime.timedelta(seconds=31500), 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody', 'GDX', 'Sokol Airport', 'Magadan'),
#  (datetime.timedelta(seconds=31500), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk'),
#  (datetime.timedelta(seconds=30300), 'VKO', 'Vnukovo International Airport', 'Moscow', 'VVO', 'Vladivostok International Airport', 'Vladivostok'),
#  (datetime.timedelta(seconds=30300), 'VVO', 'Vladivostok International Airport', 'Vladivostok', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=29700), 'DME', 'Domodedovo International Airport', 'Moscow', 'DYR', 'Ugolny Airport', 'Anadyr'),
#  (datetime.timedelta(seconds=29700), 'DYR', 'Ugolny Airport', 'Anadyr', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=29700), 'VKO', 'Vnukovo International Airport', 'Moscow', 'DYR', 'Ugolny Airport', 'Anadyr'),
#  (datetime.timedelta(seconds=29700), 'DYR', 'Ugolny Airport', 'Anadyr', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=29400), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'DYR', 'Ugolny Airport', 'Anadyr'),
#  (datetime.timedelta(seconds=29400), 'DYR', 'Ugolny Airport', 'Anadyr', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=29100), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=29100), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=28800), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=28800), 'DME', 'Domodedovo International Airport', 'Moscow', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=24600), 'CNN', 'Chulman Airport', 'Neryungri', 'ASF', 'Astrakhan Airport', 'Astrakhan'),
#  (datetime.timedelta(seconds=24600), 'ASF', 'Astrakhan Airport', 'Astrakhan', 'CNN', 'Chulman Airport', 'Neryungri'),
#  (datetime.timedelta(seconds=24000), 'CNN', 'Chulman Airport', 'Neryungri', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=24000), 'DME', 'Domodedovo International Airport', 'Moscow', 'CNN', 'Chulman Airport', 'Neryungri'),
#  (datetime.timedelta(seconds=24000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'CNN', 'Chulman Airport', 'Neryungri'),
#  (datetime.timedelta(seconds=24000), 'CNN', 'Chulman Airport', 'Neryungri', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=23100), 'YKS', 'Yakutsk Airport', 'Yakutsk', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=23100), 'SCW', 'Syktyvkar Airport', 'Syktyvkar', 'GDX', 'Sokol Airport', 'Magadan'),
#  (datetime.timedelta(seconds=23100), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'YKS', 'Yakutsk Airport', 'Yakutsk'),
#  (datetime.timedelta(seconds=23100), 'GDX', 'Sokol Airport', 'Magadan', 'SCW', 'Syktyvkar Airport', 'Syktyvkar'),
#  (datetime.timedelta(seconds=22500), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'KXK', 'Komsomolsk-on-Amur Airport', 'Komsomolsk-on-Amur'),
#  (datetime.timedelta(seconds=22500), 'KXK', 'Komsomolsk-on-Amur Airport', 'Komsomolsk-on-Amur', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=21000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=21000), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=21000), 'VKO', 'Vnukovo International Airport', 'Moscow', 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude'),
#  (datetime.timedelta(seconds=21000), 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=20700), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'MJZ', 'Mirny Airport', 'Mirnyj'),
#  (datetime.timedelta(seconds=20700), 'MJZ', 'Mirny Airport', 'Mirnyj', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=19500), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'PYJ', 'Polyarny Airport', 'Yakutia'),
#  (datetime.timedelta(seconds=19500), 'PYJ', 'Polyarny Airport', 'Yakutia', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=18900), 'CNN', 'Chulman Airport', 'Neryungri', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=18900), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'CNN', 'Chulman Airport', 'Neryungri'),
#  (datetime.timedelta(seconds=18600), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=18600), 'AER', 'Sochi International Airport', 'Sochi', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=18300), 'AAQ', 'Anapa Vityazevo Airport', 'Anapa', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=18300), 'BTK', 'Bratsk Airport', 'Bratsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=18300), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'AAQ', 'Anapa Vityazevo Airport', 'Anapa'),
#  (datetime.timedelta(seconds=18300), 'DME', 'Domodedovo International Airport', 'Moscow', 'BTK', 'Bratsk Airport', 'Bratsk'),
#  (datetime.timedelta(seconds=18000), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=18000), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=17700), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar'),
#  (datetime.timedelta(seconds=17700), 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=17700), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=17700), 'HTA', 'Chita-Kadala Airport', 'Chita', 'UFA', 'Ufa International Airport', 'Ufa'),
#  (datetime.timedelta(seconds=17700), 'UFA', 'Ufa International Airport', 'Ufa', 'HTA', 'Chita-Kadala Airport', 'Chita'),
#  (datetime.timedelta(seconds=17700), 'AER', 'Sochi International Airport', 'Sochi', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=17400), 'ABA', 'Abakan Airport', 'Abakan', 'GRV', 'Khankala Air Base', 'Grozny'),
#  (datetime.timedelta(seconds=17400), 'GRV', 'Khankala Air Base', 'Grozny', 'ABA', 'Abakan Airport', 'Abakan'),
#  (datetime.timedelta(seconds=17400), 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk', 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar'),
#  (datetime.timedelta(seconds=17400), 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar', 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk'),
#  (datetime.timedelta(seconds=16800), 'KZN', 'Kazan International Airport', 'Kazan', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=16800), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=16200), 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk', 'STW', 'Stavropol Shpakovskoye Airport', 'Stavropol'),
#  (datetime.timedelta(seconds=16200), 'STW', 'Stavropol Shpakovskoye Airport', 'Stavropol', 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk'),
#  (datetime.timedelta(seconds=15900), 'ABA', 'Abakan Airport', 'Abakan', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=15900), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=15900), 'DME', 'Domodedovo International Airport', 'Moscow', 'ABA', 'Abakan Airport', 'Abakan'),
#  (datetime.timedelta(seconds=15900), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=15600), 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=15600), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'RGK', 'Gorno-Altaysk Airport', 'Gorno-Altaysk'),
#  (datetime.timedelta(seconds=15300), 'KGP', 'Kogalym International Airport', 'Kogalym', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=15300), 'TOF', 'Bogashevo Airport', 'Tomsk', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=15300), 'AER', 'Sochi International Airport', 'Sochi', 'KGP', 'Kogalym International Airport', 'Kogalym'),
#  (datetime.timedelta(seconds=15300), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=14700), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'DYR', 'Ugolny Airport', 'Anadyr'),
#  (datetime.timedelta(seconds=14700), 'DYR', 'Ugolny Airport', 'Anadyr', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=14400), 'ABA', 'Abakan Airport', 'Abakan', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=14400), 'MJZ', 'Mirny Airport', 'Mirnyj', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=14400), 'KEJ', 'Kemerovo Airport', 'Kemorovo', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14400), 'DME', 'Domodedovo International Airport', 'Moscow', 'KEJ', 'Kemerovo Airport', 'Kemorovo'),
#  (datetime.timedelta(seconds=14400), 'CEE', 'Cherepovets Airport', 'Cherepovets', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=14400), 'VKO', 'Vnukovo International Airport', 'Moscow', 'KEJ', 'Kemerovo Airport', 'Kemorovo'),
#  (datetime.timedelta(seconds=14400), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'KEJ', 'Kemerovo Airport', 'Kemorovo'),
#  (datetime.timedelta(seconds=14400), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'CEE', 'Cherepovets Airport', 'Cherepovets'),
#  (datetime.timedelta(seconds=14400), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'ABA', 'Abakan Airport', 'Abakan'),
#  (datetime.timedelta(seconds=14400), 'KEJ', 'Kemerovo Airport', 'Kemorovo', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14400), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'MJZ', 'Mirny Airport', 'Mirnyj'),
#  (datetime.timedelta(seconds=14400), 'KEJ', 'Kemerovo Airport', 'Kemorovo', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14100), 'TOF', 'Bogashevo Airport', 'Tomsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14100), 'DME', 'Domodedovo International Airport', 'Moscow', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=14100), 'KLF', 'Grabtsevo Airport', 'Kaluga', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=14100), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'KLF', 'Grabtsevo Airport', 'Kaluga'),
#  (datetime.timedelta(seconds=14100), 'BAX', 'Barnaul Airport', 'Barnaul', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14100), 'BAX', 'Barnaul Airport', 'Barnaul', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=14100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=14100), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'GDX', 'Sokol Airport', 'Magadan'),
#  (datetime.timedelta(seconds=14100), 'GDX', 'Sokol Airport', 'Magadan', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=14100), 'BAX', 'Barnaul Airport', 'Barnaul', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=14100), 'VKO', 'Vnukovo International Airport', 'Moscow', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=13800), 'YKS', 'Yakutsk Airport', 'Yakutsk', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=13800), 'BAX', 'Barnaul Airport', 'Barnaul', 'YKS', 'Yakutsk Airport', 'Yakutsk'),
#  (datetime.timedelta(seconds=13800), 'TOF', 'Bogashevo Airport', 'Tomsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=13800), 'DME', 'Domodedovo International Airport', 'Moscow', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=13800), 'TOF', 'Bogashevo Airport', 'Tomsk', 'VOG', 'Volgograd International Airport', 'Volgograd'),
#  (datetime.timedelta(seconds=13800), 'NSK', 'Norilsk-Alykel Airport', 'Norilsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=13800), 'VOG', 'Volgograd International Airport', 'Volgograd', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=13800), 'ESL', 'Elista Airport', 'Elista', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=13800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'ESL', 'Elista Airport', 'Elista'),
#  (datetime.timedelta(seconds=13800), 'DME', 'Domodedovo International Airport', 'Moscow', 'NSK', 'Norilsk-Alykel Airport', 'Norilsk'),
#  (datetime.timedelta(seconds=13800), 'IAR', 'Tunoshna Airport', 'Yaroslavl', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=13800), 'TOF', 'Bogashevo Airport', 'Tomsk', 'IAR', 'Tunoshna Airport', 'Yaroslavl'),
#  (datetime.timedelta(seconds=13500), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'KVX', 'Pobedilovo Airport', 'Kirov'),
#  (datetime.timedelta(seconds=13500), 'AER', 'Sochi International Airport', 'Sochi', 'PEZ', 'Penza Airport', 'Penza'),
#  (datetime.timedelta(seconds=13500), 'KVX', 'Pobedilovo Airport', 'Kirov', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=13500), 'PEZ', 'Penza Airport', 'Penza', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=13500), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=13500), 'BAX', 'Barnaul Airport', 'Barnaul', 'ASF', 'Astrakhan Airport', 'Astrakhan'),
#  (datetime.timedelta(seconds=13500), 'ASF', 'Astrakhan Airport', 'Astrakhan', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=13500), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=13200), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'HTA', 'Chita-Kadala Airport', 'Chita'),
#  (datetime.timedelta(seconds=13200), 'HTA', 'Chita-Kadala Airport', 'Chita', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=13200), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'SWT', 'Strezhevoy Airport', 'Strezhevoy'),
#  (datetime.timedelta(seconds=13200), 'SGC', 'Surgut Airport', 'Surgut', 'HTA', 'Chita-Kadala Airport', 'Chita'),
#  (datetime.timedelta(seconds=13200), 'KZN', 'Kazan International Airport', 'Kazan', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=13200), 'TOF', 'Bogashevo Airport', 'Tomsk', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=13200), 'SWT', 'Strezhevoy Airport', 'Strezhevoy', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=13200), 'HTA', 'Chita-Kadala Airport', 'Chita', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=13200), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=13200), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=12900), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=12900), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk'),
#  (datetime.timedelta(seconds=12900), 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=12900), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=12600), 'URS', 'Kursk East Airport', 'Kursk', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=12600), 'NYM', 'Nadym Airport', 'Nadym', 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude'),
#  (datetime.timedelta(seconds=12600), 'SGC', 'Surgut Airport', 'Surgut', 'URS', 'Kursk East Airport', 'Kursk'),
#  (datetime.timedelta(seconds=12600), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'LPK', 'Lipetsk Airport', 'Lipetsk'),
#  (datetime.timedelta(seconds=12600), 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude', 'NYM', 'Nadym Airport', 'Nadym'),
#  (datetime.timedelta(seconds=12600), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk'),
#  (datetime.timedelta(seconds=12600), 'LPK', 'Lipetsk Airport', 'Lipetsk', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=12600), 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=12300), 'DME', 'Domodedovo International Airport', 'Moscow', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=12300), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=12300), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'TBW', 'Donskoye Airport', 'Tambow'),
#  (datetime.timedelta(seconds=12300), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=12300), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk'),
#  (datetime.timedelta(seconds=12300), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=12300), 'TBW', 'Donskoye Airport', 'Tambow', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=12300), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=12300), 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=12300), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=12000), 'NOJ', 'Noyabrsk Airport', 'Noyabrsk', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=12000), 'REN', 'Orenburg Central Airport', 'Orenburg', 'ESL', 'Elista Airport', 'Elista'),
#  (datetime.timedelta(seconds=12000), 'NYA', 'Nyagan Airport', 'Nyagan', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=12000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'NOJ', 'Noyabrsk Airport', 'Noyabrsk'),
#  (datetime.timedelta(seconds=12000), 'ESL', 'Elista Airport', 'Elista', 'REN', 'Orenburg Central Airport', 'Orenburg'),
#  (datetime.timedelta(seconds=12000), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'NYA', 'Nyagan Airport', 'Nyagan'),
#  (datetime.timedelta(seconds=11700), 'UFA', 'Ufa International Airport', 'Ufa', 'UCT', 'Ukhta Airport', 'Ukhta'),
#  (datetime.timedelta(seconds=11700), 'VKO', 'Vnukovo International Airport', 'Moscow', 'NOJ', 'Noyabrsk Airport', 'Noyabrsk'),
#  (datetime.timedelta(seconds=11700), 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11700), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'NYM', 'Nadym Airport', 'Nadym'),
#  (datetime.timedelta(seconds=11700), 'VKO', 'Vnukovo International Airport', 'Moscow', 'OMS', 'Omsk Central Airport', 'Omsk'),
#  (datetime.timedelta(seconds=11700), 'UCT', 'Ukhta Airport', 'Ukhta', 'UFA', 'Ufa International Airport', 'Ufa'),
#  (datetime.timedelta(seconds=11700), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'VVO', 'Vladivostok International Airport', 'Vladivostok'),
#  (datetime.timedelta(seconds=11700), 'NOJ', 'Noyabrsk Airport', 'Noyabrsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11700), 'OMS', 'Omsk Central Airport', 'Omsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11700), 'NYM', 'Nadym Airport', 'Nadym', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=11700), 'DME', 'Domodedovo International Airport', 'Moscow', 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk'),
#  (datetime.timedelta(seconds=11700), 'VVO', 'Vladivostok International Airport', 'Vladivostok', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=11400), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'KGP', 'Kogalym International Airport', 'Kogalym'),
#  (datetime.timedelta(seconds=11400), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=11400), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'KYZ', 'Kyzyl Airport', 'Kyzyl'),
#  (datetime.timedelta(seconds=11400), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'NOJ', 'Noyabrsk Airport', 'Noyabrsk'),
#  (datetime.timedelta(seconds=11400), 'KYZ', 'Kyzyl Airport', 'Kyzyl', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=11400), 'DME', 'Domodedovo International Airport', 'Moscow', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=11400), 'NOJ', 'Noyabrsk Airport', 'Noyabrsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11400), 'KGP', 'Kogalym International Airport', 'Kogalym', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=11400), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11400), 'SGC', 'Surgut Airport', 'Surgut', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=11100), 'DME', 'Domodedovo International Airport', 'Moscow', 'NYM', 'Nadym Airport', 'Nadym'),
#  (datetime.timedelta(seconds=11100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=11100), 'NYM', 'Nadym Airport', 'Nadym', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11100), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=11100), 'KUF', 'Kurumoch International Airport', 'Samara', 'URS', 'Kursk East Airport', 'Kursk'),
#  (datetime.timedelta(seconds=11100), 'URS', 'Kursk East Airport', 'Kursk', 'KUF', 'Kurumoch International Airport', 'Samara'),
#  (datetime.timedelta(seconds=10800), 'EYK', 'Beloyarskiy Airport', 'Beloyarsky', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=10800), 'SGC', 'Surgut Airport', 'Surgut', 'IKT', 'Irkutsk Airport', 'Irkutsk'),
#  (datetime.timedelta(seconds=10800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'NFG', 'Nefteyugansk Airport', 'Nefteyugansk'),
#  (datetime.timedelta(seconds=10800), 'NFG', 'Nefteyugansk Airport', 'Nefteyugansk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=10800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'OMS', 'Omsk Central Airport', 'Omsk'),
#  (datetime.timedelta(seconds=10800), 'OMS', 'Omsk Central Airport', 'Omsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=10800), 'IKT', 'Irkutsk Airport', 'Irkutsk', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=10800), 'NFG', 'Nefteyugansk Airport', 'Nefteyugansk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=10800), 'VKO', 'Vnukovo International Airport', 'Moscow', 'NFG', 'Nefteyugansk Airport', 'Nefteyugansk'),
#  (datetime.timedelta(seconds=10800), 'KRO', 'Kurgan Airport', 'Kurgan', 'EYK', 'Beloyarskiy Airport', 'Beloyarsky'),
#  (datetime.timedelta(seconds=10500), 'TJM', 'Roshchino International Airport', 'Tyumen', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=10500), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=10200), 'SLY', 'Salekhard Airport', 'Salekhard', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=10200), 'MJZ', 'Mirny Airport', 'Mirnyj', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=10200), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'PYJ', 'Polyarny Airport', 'Yakutia'),
#  (datetime.timedelta(seconds=10200), 'PYJ', 'Polyarny Airport', 'Yakutia', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=10200), 'CNN', 'Chulman Airport', 'Neryungri', 'MJZ', 'Mirny Airport', 'Mirnyj'),
#  (datetime.timedelta(seconds=10200), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'MJZ', 'Mirny Airport', 'Mirnyj'),
#  (datetime.timedelta(seconds=10200), 'MJZ', 'Mirny Airport', 'Mirnyj', 'CNN', 'Chulman Airport', 'Neryungri'),
#  (datetime.timedelta(seconds=10200), 'VKO', 'Vnukovo International Airport', 'Moscow', 'SLY', 'Salekhard Airport', 'Salekhard'),
#  (datetime.timedelta(seconds=9900), 'KGD', 'Khrabrovo Airport', 'Kaliningrad', 'ESL', 'Elista Airport', 'Elista'),
#  (datetime.timedelta(seconds=9900), 'CSY', 'Cheboksary Airport', 'Cheboksary', 'VOG', 'Volgograd International Airport', 'Volgograd'),
#  (datetime.timedelta(seconds=9900), 'ESL', 'Elista Airport', 'Elista', 'KGD', 'Khrabrovo Airport', 'Kaliningrad'),
#  (datetime.timedelta(seconds=9900), 'VOG', 'Volgograd International Airport', 'Volgograd', 'CSY', 'Cheboksary Airport', 'Cheboksary'),
#  (datetime.timedelta(seconds=9900), 'VKO', 'Vnukovo International Airport', 'Moscow', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=9900), 'DME', 'Domodedovo International Airport', 'Moscow', 'VKT', 'Vorkuta Airport', 'Vorkuta'),
#  (datetime.timedelta(seconds=9900), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9900), 'VKT', 'Vorkuta Airport', 'Vorkuta', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9900), 'KVX', 'Pobedilovo Airport', 'Kirov', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=9900), 'EGO', 'Belgorod International Airport', 'Belgorod', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=9900), 'AER', 'Sochi International Airport', 'Sochi', 'EGO', 'Belgorod International Airport', 'Belgorod'),
#  (datetime.timedelta(seconds=9900), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'KVX', 'Pobedilovo Airport', 'Kirov'),
#  (datetime.timedelta(seconds=9600), 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk', 'YKS', 'Yakutsk Airport', 'Yakutsk'),
#  (datetime.timedelta(seconds=9600), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'UKX', 'Ust-Kut Airport', 'Ust-Kut'),
#  (datetime.timedelta(seconds=9600), 'PYJ', 'Polyarny Airport', 'Yakutia', 'KEJ', 'Kemerovo Airport', 'Kemorovo'),
#  (datetime.timedelta(seconds=9600), 'SGC', 'Surgut Airport', 'Surgut', 'VKT', 'Vorkuta Airport', 'Vorkuta'),
#  (datetime.timedelta(seconds=9600), 'UKX', 'Ust-Kut Airport', 'Ust-Kut', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=9600), 'YKS', 'Yakutsk Airport', 'Yakutsk', 'UUS', 'Yuzhno-Sakhalinsk Airport', 'Yuzhno-Sakhalinsk'),
#  (datetime.timedelta(seconds=9600), 'KLF', 'Grabtsevo Airport', 'Kaluga', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=9600), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'KLF', 'Grabtsevo Airport', 'Kaluga'),
#  (datetime.timedelta(seconds=9600), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'VKT', 'Vorkuta Airport', 'Vorkuta'),
#  (datetime.timedelta(seconds=9600), 'KEJ', 'Kemerovo Airport', 'Kemorovo', 'PYJ', 'Polyarny Airport', 'Yakutia'),
#  (datetime.timedelta(seconds=9600), 'VKT', 'Vorkuta Airport', 'Vorkuta', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9600), 'VKT', 'Vorkuta Airport', 'Vorkuta', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=9300), 'REN', 'Orenburg Central Airport', 'Orenburg', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=9300), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=9300), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'VKT', 'Vorkuta Airport', 'Vorkuta'),
#  (datetime.timedelta(seconds=9300), 'VKT', 'Vorkuta Airport', 'Vorkuta', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=9300), 'DME', 'Domodedovo International Airport', 'Moscow', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=9300), 'DME', 'Domodedovo International Airport', 'Moscow', 'EYK', 'Beloyarskiy Airport', 'Beloyarsky'),
#  (datetime.timedelta(seconds=9300), 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk', 'OSW', 'Orsk Airport', 'Orsk'),
#  (datetime.timedelta(seconds=9300), 'TJM', 'Roshchino International Airport', 'Tyumen', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=9300), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=9300), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=9300), 'OSW', 'Orsk Airport', 'Orsk', 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=9300), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'NSK', 'Norilsk-Alykel Airport', 'Norilsk'),
#  (datetime.timedelta(seconds=9300), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'REN', 'Orenburg Central Airport', 'Orenburg'),
#  (datetime.timedelta(seconds=9300), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9300), 'EYK', 'Beloyarskiy Airport', 'Beloyarsky', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9300), 'NSK', 'Norilsk-Alykel Airport', 'Norilsk', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=9000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'ESL', 'Elista Airport', 'Elista'),
#  (datetime.timedelta(seconds=9000), 'ESL', 'Elista Airport', 'Elista', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=9000), 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk', 'ULY', 'Ulyanovsk East Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=9000), 'ULY', 'Ulyanovsk East Airport', 'Ulyanovsk', 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk'),
#  (datetime.timedelta(seconds=9000), 'VKO', 'Vnukovo International Airport', 'Moscow', 'NYA', 'Nyagan Airport', 'Nyagan'),
#  (datetime.timedelta(seconds=9000), 'VKO', 'Vnukovo International Airport', 'Moscow', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=9000), 'KVX', 'Pobedilovo Airport', 'Kirov', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9000), 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude', 'YKS', 'Yakutsk Airport', 'Yakutsk'),
#  (datetime.timedelta(seconds=9000), 'KRO', 'Kurgan Airport', 'Kurgan', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9000), 'NSK', 'Norilsk-Alykel Airport', 'Norilsk', 'NYM', 'Nadym Airport', 'Nadym'),
#  (datetime.timedelta(seconds=9000), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'NYA', 'Nyagan Airport', 'Nyagan'),
#  (datetime.timedelta(seconds=9000), 'KRO', 'Kurgan Airport', 'Kurgan', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9000), 'NYA', 'Nyagan Airport', 'Nyagan', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9000), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=9000), 'YKS', 'Yakutsk Airport', 'Yakutsk', 'UUD', 'Ulan-Ude Airport (Mukhino)', 'Ulan-ude'),
#  (datetime.timedelta(seconds=9000), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'STW', 'Stavropol Shpakovskoye Airport', 'Stavropol'),
#  (datetime.timedelta(seconds=9000), 'NYA', 'Nyagan Airport', 'Nyagan', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=9000), 'STW', 'Stavropol Shpakovskoye Airport', 'Stavropol', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=9000), 'NYM', 'Nadym Airport', 'Nadym', 'NSK', 'Norilsk-Alykel Airport', 'Norilsk'),
#  (datetime.timedelta(seconds=9000), 'DME', 'Domodedovo International Airport', 'Moscow', 'KVX', 'Pobedilovo Airport', 'Kirov'),
#  (datetime.timedelta(seconds=8700), 'DME', 'Domodedovo International Airport', 'Moscow', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=8700), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=8700), 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar', 'KGD', 'Khrabrovo Airport', 'Kaliningrad'),
#  (datetime.timedelta(seconds=8700), 'KRO', 'Kurgan Airport', 'Kurgan', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=8700), 'KGD', 'Khrabrovo Airport', 'Kaliningrad', 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar'),
#  (datetime.timedelta(seconds=8700), 'KRO', 'Kurgan Airport', 'Kurgan', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8400), 'NBC', 'Begishevo Airport', 'Nizhnekamsk', 'SCW', 'Syktyvkar Airport', 'Syktyvkar'),
#  (datetime.timedelta(seconds=8400), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody'),
#  (datetime.timedelta(seconds=8400), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=8400), 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=8400), 'EYK', 'Beloyarskiy Airport', 'Beloyarsky', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=8400), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=8400), 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=8400), 'SCW', 'Syktyvkar Airport', 'Syktyvkar', 'NBC', 'Begishevo Airport', 'Nizhnekamsk'),
#  (datetime.timedelta(seconds=8400), 'SGC', 'Surgut Airport', 'Surgut', 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk'),
#  (datetime.timedelta(seconds=8400), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=8400), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=8400), 'TJM', 'Roshchino International Airport', 'Tyumen', 'EYK', 'Beloyarskiy Airport', 'Beloyarsky'),
#  (datetime.timedelta(seconds=8100), 'TJM', 'Roshchino International Airport', 'Tyumen', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=8100), 'MCX', 'Uytash Airport', 'Makhachkala', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8100), 'MCX', 'Uytash Airport', 'Makhachkala', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8100), 'DME', 'Domodedovo International Airport', 'Moscow', 'MCX', 'Uytash Airport', 'Makhachkala'),
#  (datetime.timedelta(seconds=8100), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk'),
#  (datetime.timedelta(seconds=8100), 'IAR', 'Tunoshna Airport', 'Yaroslavl', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=8100), 'DME', 'Domodedovo International Airport', 'Moscow', 'URJ', 'Uray Airport', 'Uraj'),
#  (datetime.timedelta(seconds=8100), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=8100), 'KEJ', 'Kemerovo Airport', 'Kemorovo', 'KYZ', 'Kyzyl Airport', 'Kyzyl'),
#  (datetime.timedelta(seconds=8100), 'AER', 'Sochi International Airport', 'Sochi', 'IAR', 'Tunoshna Airport', 'Yaroslavl'),
#  (datetime.timedelta(seconds=8100), 'URJ', 'Uray Airport', 'Uraj', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=8100), 'KLF', 'Grabtsevo Airport', 'Kaluga', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=8100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=8100), 'KYZ', 'Kyzyl Airport', 'Kyzyl', 'KEJ', 'Kemerovo Airport', 'Kemorovo'),
#  (datetime.timedelta(seconds=8100), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'MCX', 'Uytash Airport', 'Makhachkala'),
#  (datetime.timedelta(seconds=8100), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'KLF', 'Grabtsevo Airport', 'Kaluga'),
#  (datetime.timedelta(seconds=8100), 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=8100), 'USK', 'Usinsk Airport', 'Usinsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8100), 'DME', 'Domodedovo International Airport', 'Moscow', 'USK', 'Usinsk Airport', 'Usinsk'),
#  (datetime.timedelta(seconds=8100), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=8100), 'TJM', 'Roshchino International Airport', 'Tyumen', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=7800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola'),
#  (datetime.timedelta(seconds=7800), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=7800), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'OSW', 'Orsk Airport', 'Orsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'NYM', 'Nadym Airport', 'Nadym'),
#  (datetime.timedelta(seconds=7800), 'VKO', 'Vnukovo International Airport', 'Moscow', 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola'),
#  (datetime.timedelta(seconds=7800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'NNM', 'Naryan Mar Airport', 'Naryan-Mar'),
#  (datetime.timedelta(seconds=7800), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'BAX', 'Barnaul Airport', 'Barnaul'),
#  (datetime.timedelta(seconds=7800), 'DME', 'Domodedovo International Airport', 'Moscow', 'NNM', 'Naryan Mar Airport', 'Naryan-Mar'),
#  (datetime.timedelta(seconds=7800), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=7800), 'KRO', 'Kurgan Airport', 'Kurgan', 'OSW', 'Orsk Airport', 'Orsk'),
#  (datetime.timedelta(seconds=7800), 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'DME', 'Domodedovo International Airport', 'Moscow', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=7800), 'USK', 'Usinsk Airport', 'Usinsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'AER', 'Sochi International Airport', 'Sochi', 'IWA', 'Ivanovo South Airport', 'Ivanovo'),
#  (datetime.timedelta(seconds=7800), 'NYM', 'Nadym Airport', 'Nadym', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=7800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'USK', 'Usinsk Airport', 'Usinsk'),
#  (datetime.timedelta(seconds=7800), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'SLY', 'Salekhard Airport', 'Salekhard'),
#  (datetime.timedelta(seconds=7800), 'SLY', 'Salekhard Airport', 'Salekhard', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=7800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=7800), 'VKO', 'Vnukovo International Airport', 'Moscow', 'OSW', 'Orsk Airport', 'Orsk'),
#  (datetime.timedelta(seconds=7800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'OGZ', 'Beslan Airport', 'Beslan'),
#  (datetime.timedelta(seconds=7800), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=7800), 'NNM', 'Naryan Mar Airport', 'Naryan-Mar', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'NNM', 'Naryan Mar Airport', 'Naryan-Mar', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'IWA', 'Ivanovo South Airport', 'Ivanovo', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=7800), 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=7800), 'BAX', 'Barnaul Airport', 'Barnaul', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=7800), 'OGZ', 'Beslan Airport', 'Beslan', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7800), 'OSW', 'Orsk Airport', 'Orsk', 'KRO', 'Kurgan Airport', 'Kurgan'),
#  (datetime.timedelta(seconds=7800), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=7500), 'PKV', 'Pskov Airport', 'Pskov', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7500), 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=7500), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=7500), 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7500), 'DME', 'Domodedovo International Airport', 'Moscow', 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola'),
#  (datetime.timedelta(seconds=7500), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=7500), 'OMS', 'Omsk Central Airport', 'Omsk', 'VKT', 'Vorkuta Airport', 'Vorkuta'),
#  (datetime.timedelta(seconds=7500), 'GRV', 'Khankala Air Base', 'Grozny', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7500), 'DME', 'Domodedovo International Airport', 'Moscow', 'PKV', 'Pskov Airport', 'Pskov'),
#  (datetime.timedelta(seconds=7500), 'DME', 'Domodedovo International Airport', 'Moscow', 'GRV', 'Khankala Air Base', 'Grozny'),
#  (datetime.timedelta(seconds=7500), 'MMK', 'Murmansk Airport', 'Murmansk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7500), 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=7500), 'VKT', 'Vorkuta Airport', 'Vorkuta', 'OMS', 'Omsk Central Airport', 'Omsk'),
#  (datetime.timedelta(seconds=7500), 'AER', 'Sochi International Airport', 'Sochi', 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod'),
#  (datetime.timedelta(seconds=7500), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'UIK', 'Ust-Ilimsk Airport', 'Ust Ilimsk'),
#  (datetime.timedelta(seconds=7500), 'VKO', 'Vnukovo International Airport', 'Moscow', 'MMK', 'Murmansk Airport', 'Murmansk'),
#  (datetime.timedelta(seconds=7200), 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=7200), 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar', 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola'),
#  (datetime.timedelta(seconds=7200), 'VKO', 'Vnukovo International Airport', 'Moscow', 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk'),
#  (datetime.timedelta(seconds=7200), 'NAL', 'Nalchik Airport', 'Nalchik', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7200), 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod', 'NAL', 'Nalchik Airport', 'Nalchik'),
#  (datetime.timedelta(seconds=7200), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'IAR', 'Tunoshna Airport', 'Yaroslavl'),
#  (datetime.timedelta(seconds=7200), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'KJA', 'Yemelyanovo Airport', 'Krasnoyarsk'),
#  (datetime.timedelta(seconds=7200), 'IAR', 'Tunoshna Airport', 'Yaroslavl', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=7200), 'KZN', 'Kazan International Airport', 'Kazan', 'MCX', 'Uytash Airport', 'Makhachkala'),
#  (datetime.timedelta(seconds=7200), 'OGZ', 'Beslan Airport', 'Beslan', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7200), 'MCX', 'Uytash Airport', 'Makhachkala', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=7200), 'DME', 'Domodedovo International Airport', 'Moscow', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=7200), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7200), 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=7200), 'NAL', 'Nalchik Airport', 'Nalchik', 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod'),
#  (datetime.timedelta(seconds=7200), 'VKO', 'Vnukovo International Airport', 'Moscow', 'OGZ', 'Beslan Airport', 'Beslan'),
#  (datetime.timedelta(seconds=7200), 'JOK', 'Yoshkar-Ola Airport', 'Yoshkar-Ola', 'KRR', 'Krasnodar Pashkovsky International Airport', 'Krasnodar'),
#  (datetime.timedelta(seconds=7200), 'DME', 'Domodedovo International Airport', 'Moscow', 'NAL', 'Nalchik Airport', 'Nalchik'),
#  (datetime.timedelta(seconds=6900), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'PEZ', 'Penza Airport', 'Penza'),
#  (datetime.timedelta(seconds=6900), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'PKV', 'Pskov Airport', 'Pskov'),
# ...
#  (datetime.timedelta(seconds=4500), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'VOG', 'Volgograd International Airport', 'Volgograd'),
#  (datetime.timedelta(seconds=4500), 'UFA', 'Ufa International Airport', 'Ufa', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=4500), 'VOG', 'Volgograd International Airport', 'Volgograd', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=4500), 'ULY', 'Ulyanovsk East Airport', 'Ulyanovsk', 'RTW', 'Saratov Central Airport', 'Saratov'),
#  (datetime.timedelta(seconds=4500), 'SGC', 'Surgut Airport', 'Surgut', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=4200), 'MJZ', 'Mirny Airport', 'Mirnyj', 'YKS', 'Yakutsk Airport', 'Yakutsk'),
#  (datetime.timedelta(seconds=4200), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=4200), 'SGC', 'Surgut Airport', 'Surgut', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=4200), 'VOG', 'Volgograd International Airport', 'Volgograd', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=4200), 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=4200), 'VKO', 'Vnukovo International Airport', 'Moscow', 'VOG', 'Volgograd International Airport', 'Volgograd'),
#  (datetime.timedelta(seconds=4200), 'YKS', 'Yakutsk Airport', 'Yakutsk', 'MJZ', 'Mirny Airport', 'Mirnyj'),
#  (datetime.timedelta(seconds=4200), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod'),
#  (datetime.timedelta(seconds=3900), 'LPK', 'Lipetsk Airport', 'Lipetsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3900), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'SCW', 'Syktyvkar Airport', 'Syktyvkar'),
#  (datetime.timedelta(seconds=3900), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3900), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'GDZ', 'Gelendzhik Airport', 'Gelendzhik'),
#  (datetime.timedelta(seconds=3900), 'GDZ', 'Gelendzhik Airport', 'Gelendzhik', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=3900), 'NOJ', 'Noyabrsk Airport', 'Noyabrsk', 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy'),
#  (datetime.timedelta(seconds=3900), 'DME', 'Domodedovo International Airport', 'Moscow', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=3900), 'VKO', 'Vnukovo International Airport', 'Moscow', 'RTW', 'Saratov Central Airport', 'Saratov'),
#  (datetime.timedelta(seconds=3900), 'ULY', 'Ulyanovsk East Airport', 'Ulyanovsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3900), 'KUF', 'Kurumoch International Airport', 'Samara', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3900), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'ULY', 'Ulyanovsk East Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=3900), 'SCW', 'Syktyvkar Airport', 'Syktyvkar', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=3900), 'RTW', 'Saratov Central Airport', 'Saratov', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3900), 'NUX', 'Novy Urengoy Airport', 'Novy Urengoy', 'NOJ', 'Noyabrsk Airport', 'Noyabrsk'),
#  (datetime.timedelta(seconds=3900), 'DME', 'Domodedovo International Airport', 'Moscow', 'LPK', 'Lipetsk Airport', 'Lipetsk'),
#  (datetime.timedelta(seconds=3900), 'DME', 'Domodedovo International Airport', 'Moscow', 'KUF', 'Kurumoch International Airport', 'Samara'),
#  (datetime.timedelta(seconds=3600), 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=3600), 'KYZ', 'Kyzyl Airport', 'Kyzyl', 'ABA', 'Abakan Airport', 'Abakan'),
#  (datetime.timedelta(seconds=3600), 'RTW', 'Saratov Central Airport', 'Saratov', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3600), 'KVX', 'Pobedilovo Airport', 'Kirov', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3600), 'VKO', 'Vnukovo International Airport', 'Moscow', 'PES', 'Petrozavodsk Airport', 'Petrozavodsk'),
#  (datetime.timedelta(seconds=3600), 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=3600), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'NJC', 'Nizhnevartovsk Airport', 'Nizhnevartovsk'),
#  (datetime.timedelta(seconds=3600), 'ABA', 'Abakan Airport', 'Abakan', 'KYZ', 'Kyzyl Airport', 'Kyzyl'),
#  (datetime.timedelta(seconds=3600), 'TOF', 'Bogashevo Airport', 'Tomsk', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=3600), 'PES', 'Petrozavodsk Airport', 'Petrozavodsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3600), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod'),
#  (datetime.timedelta(seconds=3600), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'TOF', 'Bogashevo Airport', 'Tomsk'),
#  (datetime.timedelta(seconds=3600), 'DME', 'Domodedovo International Airport', 'Moscow', 'RTW', 'Saratov Central Airport', 'Saratov'),
#  (datetime.timedelta(seconds=3600), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'KVX', 'Pobedilovo Airport', 'Kirov'),
#  (datetime.timedelta(seconds=3300), 'KZN', 'Kazan International Airport', 'Kazan', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'VKO', 'Vnukovo International Airport', 'Moscow', 'CSY', 'Cheboksary Airport', 'Cheboksary'),
#  (datetime.timedelta(seconds=3300), 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=3300), 'KZN', 'Kazan International Airport', 'Kazan', 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk'),
#  (datetime.timedelta(seconds=3300), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'HMA', 'Khanty Mansiysk Airport', 'Khanty-Mansiysk'),
#  (datetime.timedelta(seconds=3300), 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'CSY', 'Cheboksary Airport', 'Cheboksary', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'NNM', 'Naryan Mar Airport', 'Naryan-Mar', 'ARH', 'Talagi Airport', 'Arkhangelsk'),
#  (datetime.timedelta(seconds=3300), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=3300), 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3300), 'VKO', 'Vnukovo International Airport', 'Moscow', 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=3300), 'DME', 'Domodedovo International Airport', 'Moscow', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=3300), 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=3300), 'ARH', 'Talagi Airport', 'Arkhangelsk', 'NNM', 'Naryan Mar Airport', 'Naryan-Mar'),
#  (datetime.timedelta(seconds=3300), 'DME', 'Domodedovo International Airport', 'Moscow', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=3300), 'DME', 'Domodedovo International Airport', 'Moscow', 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=3000), 'BQS', 'Ignatyevo Airport', 'Blagoveschensk', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=3000), 'AAQ', 'Anapa Vityazevo Airport', 'Anapa', 'EGO', 'Belgorod International Airport', 'Belgorod'),
#  (datetime.timedelta(seconds=3000), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'VVO', 'Vladivostok International Airport', 'Vladivostok'),
#  (datetime.timedelta(seconds=3000), 'VKO', 'Vnukovo International Airport', 'Moscow', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=3000), 'CSY', 'Cheboksary Airport', 'Cheboksary', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3000), 'EGO', 'Belgorod International Airport', 'Belgorod', 'AAQ', 'Anapa Vityazevo Airport', 'Anapa'),
#  (datetime.timedelta(seconds=3000), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk'),
#  (datetime.timedelta(seconds=3000), 'ULV', 'Ulyanovsk Baratayevka Airport', 'Ulyanovsk', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=3000), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'CSY', 'Cheboksary Airport', 'Cheboksary'),
#  (datetime.timedelta(seconds=3000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3000), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'LED', 'Pulkovo Airport', 'St. Petersburg'),
#  (datetime.timedelta(seconds=3000), 'LED', 'Pulkovo Airport', 'St. Petersburg', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=3000), 'VVO', 'Vladivostok International Airport', 'Vladivostok', 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk'),
#  (datetime.timedelta(seconds=3000), 'KHV', 'Khabarovsk-Novy Airport', 'Khabarovsk', 'BQS', 'Ignatyevo Airport', 'Blagoveschensk'),
#  (datetime.timedelta(seconds=2700), 'SGC', 'Surgut Airport', 'Surgut', 'OVS', 'Sovetskiy Airport', 'Sovetskiy'),
#  (datetime.timedelta(seconds=2700), 'SKX', 'Saransk Airport', 'Saransk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=2700), 'EGO', 'Belgorod International Airport', 'Belgorod', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=2700), 'SKX', 'Saransk Airport', 'Saransk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=2700), 'OVS', 'Sovetskiy Airport', 'Sovetskiy', 'SGC', 'Surgut Airport', 'Surgut'),
#  (datetime.timedelta(seconds=2700), 'VKO', 'Vnukovo International Airport', 'Moscow', 'SKX', 'Saransk Airport', 'Saransk'),
#  (datetime.timedelta(seconds=2700), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'SKX', 'Saransk Airport', 'Saransk'),
#  (datetime.timedelta(seconds=2700), 'DME', 'Domodedovo International Airport', 'Moscow', 'EGO', 'Belgorod International Airport', 'Belgorod'),
#  (datetime.timedelta(seconds=2400), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk'),
#  (datetime.timedelta(seconds=2400), 'CEK', 'Chelyabinsk Balandino Airport', 'Chelyabinsk', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=2100), 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=2100), 'DME', 'Domodedovo International Airport', 'Moscow', 'VOZ', 'Voronezh International Airport', 'Voronezh'),
#  (datetime.timedelta(seconds=2100), 'VOZ', 'Voronezh International Airport', 'Voronezh', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=2100), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'MQF', 'Magnitogorsk International Airport', 'Magnetiogorsk'),
#  (datetime.timedelta(seconds=2100), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'AER', 'Sochi International Airport', 'Sochi'),
#  (datetime.timedelta(seconds=2100), 'DME', 'Domodedovo International Airport', 'Moscow', 'URS', 'Kursk East Airport', 'Kursk'),
#  (datetime.timedelta(seconds=2100), 'URS', 'Kursk East Airport', 'Kursk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=2100), 'AER', 'Sochi International Airport', 'Sochi', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=1800), 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody', 'MCX', 'Uytash Airport', 'Makhachkala'),
#  (datetime.timedelta(seconds=1800), 'ROV', 'Rostov-on-Don Airport', 'Rostov', 'VOG', 'Volgograd International Airport', 'Volgograd'),
#  (datetime.timedelta(seconds=1800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod'),
#  (datetime.timedelta(seconds=1800), 'BZK', 'Bryansk Airport', 'Bryansk', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=1800), 'REN', 'Orenburg Central Airport', 'Orenburg', 'UUA', 'Bugulma Airport', 'Bugulma'),
#  (datetime.timedelta(seconds=1800), 'BZK', 'Bryansk Airport', 'Bryansk', 'DME', 'Domodedovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=1800), 'UUA', 'Bugulma Airport', 'Bugulma', 'REN', 'Orenburg Central Airport', 'Orenburg'),
#  (datetime.timedelta(seconds=1800), 'GOJ', 'Nizhny Novgorod Strigino International Airport', 'Nizhniy Novgorod', 'SVO', 'Sheremetyevo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=1800), 'DME', 'Domodedovo International Airport', 'Moscow', 'BZK', 'Bryansk Airport', 'Bryansk'),
#  (datetime.timedelta(seconds=1800), 'MCX', 'Uytash Airport', 'Makhachkala', 'MRV', 'Mineralnyye Vody Airport', 'Mineralnye Vody'),
#  (datetime.timedelta(seconds=1800), 'VOG', 'Volgograd International Airport', 'Volgograd', 'ROV', 'Rostov-on-Don Airport', 'Rostov'),
#  (datetime.timedelta(seconds=1800), 'SVO', 'Sheremetyevo International Airport', 'Moscow', 'BZK', 'Bryansk Airport', 'Bryansk'),
#  (datetime.timedelta(seconds=1500), 'URJ', 'Uray Airport', 'Uraj', 'TJM', 'Roshchino International Airport', 'Tyumen'),
#  (datetime.timedelta(seconds=1500), 'OVB', 'Tolmachevo Airport', 'Novosibirsk', 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk'),
#  (datetime.timedelta(seconds=1500), 'KVX', 'Pobedilovo Airport', 'Kirov', 'KZN', 'Kazan International Airport', 'Kazan'),
#  (datetime.timedelta(seconds=1500), 'UFA', 'Ufa International Airport', 'Ufa', 'REN', 'Orenburg Central Airport', 'Orenburg'),
#  (datetime.timedelta(seconds=1500), 'NOZ', 'Spichenkovo Airport', 'Novokuznetsk', 'OVB', 'Tolmachevo Airport', 'Novosibirsk'),
#  (datetime.timedelta(seconds=1500), 'REN', 'Orenburg Central Airport', 'Orenburg', 'UFA', 'Ufa International Airport', 'Ufa'),
#  (datetime.timedelta(seconds=1500), 'VKO', 'Vnukovo International Airport', 'Moscow', 'BZK', 'Bryansk Airport', 'Bryansk'),
#  (datetime.timedelta(seconds=1500), 'PEE', 'Bolshoye Savino Airport', 'Perm', 'SVX', 'Koltsovo Airport', 'Yekaterinburg'),
#  (datetime.timedelta(seconds=1500), 'NBC', 'Begishevo Airport', 'Nizhnekamsk', 'CSY', 'Cheboksary Airport', 'Cheboksary'),
#  (datetime.timedelta(seconds=1500), 'TJM', 'Roshchino International Airport', 'Tyumen', 'URJ', 'Uray Airport', 'Uraj'),
#  (datetime.timedelta(seconds=1500), 'EGO', 'Belgorod International Airport', 'Belgorod', 'BZK', 'Bryansk Airport', 'Bryansk'),
#  (datetime.timedelta(seconds=1500), 'BZK', 'Bryansk Airport', 'Bryansk', 'EGO', 'Belgorod International Airport', 'Belgorod'),
#  (datetime.timedelta(seconds=1500), 'SVX', 'Koltsovo Airport', 'Yekaterinburg', 'PEE', 'Bolshoye Savino Airport', 'Perm'),
#  (datetime.timedelta(seconds=1500), 'CSY', 'Cheboksary Airport', 'Cheboksary', 'NBC', 'Begishevo Airport', 'Nizhnekamsk'),
#  (datetime.timedelta(seconds=1500), 'BZK', 'Bryansk Airport', 'Bryansk', 'VKO', 'Vnukovo International Airport', 'Moscow'),
#  (datetime.timedelta(seconds=1500), 'KZN', 'Kazan International Airport', 'Kazan', 'KVX', 'Pobedilovo Airport', 'Kirov')]

# %% [markdown]
# ## Задание 8:
# Определить, на какой аэропорт лежит максимальная нагрузка по обслуживанию отправлений и прибытий самолетов?
#
# Вывести название аэропорта и город, где он находится.

# %%
# %%sql
# WITH airport_load AS (
#     SELECT
#         airport_code,
#         SUM(departures) AS total_departures,
#         SUM(arrivals) AS total_arrivals,
#         SUM(departures + arrivals) AS total_load
#     FROM (
#         SELECT
#             departure_airport AS airport_code,
#             COUNT(*) AS departures,
#             0 AS arrivals
#         FROM flights
#         GROUP BY departure_airport
#
#         UNION ALL
#
#         SELECT
#             arrival_airport AS airport_code,
#             0 AS departures,
#             COUNT(*) AS arrivals
#         FROM flights
#         GROUP BY arrival_airport
#     ) AS load_data
#     GROUP BY airport_code
# )
# SELECT
#     ad.airport_name->>'en' AS airport_name,
#     ad.city->>'en' AS city,
#     al.total_load
# FROM
#     airport_load al
# JOIN airports_data ad ON al.airport_code = ad.airport_code
# ORDER BY al.total_load DESC
# LIMIT 1;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 1 rows affected.
# [('Domodedovo International Airport', 'Moscow', Decimal('41753'))]

# %% [markdown]
# ## Задание 9:
#
# Вывести среднее количество мест в самолетах по кажому классу обслуживания. Требования к формату вывода - две цифры после запятой.
#
# Пример:
#
# | fare_conditions | avg_seat_count |
# |----------------|---------------|
# | Business       | 100.01         |
# | Comfort        | 558.23         |
# | Economy        | 15.52        |

# %%
# %%sql
# SELECT
#     fare_conditions,
#     ROUND(AVG(seat_count), 2) AS avg_seat_count
# FROM (
#     SELECT
#         fare_conditions,
#         COUNT(*) AS seat_count
#     FROM seats
#     GROUP BY aircraft_code, fare_conditions
# ) AS seat_data
# GROUP BY fare_conditions;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 3 rows affected.
# [('Business', Decimal('21.71')),
#  ('Comfort', Decimal('48.00')),
#  ('Economy', Decimal('126.56'))]

# %% [markdown]
# ## Задание 10:

# %% [markdown]
# Найти и вывести на экран информацию о самом дорогом перелете. Вывести следующую информацию:
# - flight_id	(id рейса)
# - final_amount (общая выручка за данный рейс = сумма выручки за все проданные билеты)
# - departure_airport	(название аэропорта отправки самолета)
# - departure_city (название города аэропорта отправки)
# - arrival_airport	(название аэропорта прибытия самолета)
# - arrival_city (город прибытия)
#
# Выведите статистику выполнения запроса с использованием команды EXPLAIN ANALYZE. Проанализуйте полученный отчет. Какие рекомендации даются по оптимизации запроса? Попробуйте применить рекомендации.
#
# Сколько всего рейсов с максимальной суммой выручки?

# %%
# %%sql
# WITH flight_revenue AS (
#     SELECT
#         flight_id,
#         SUM(amount) AS final_amount
#     FROM ticket_flights
#     GROUP BY flight_id
# ),
# max_revenue AS (
#     SELECT
#         MAX(final_amount) AS max_amount
#     FROM flight_revenue
# ),
# most_expensive_flights AS (
#     SELECT
#         fr.flight_id,
#         fr.final_amount
#     FROM flight_revenue fr
#     JOIN max_revenue mr ON fr.final_amount = mr.max_amount
# )
# SELECT
#     mf.flight_id,
#     mf.final_amount,
#     dep.airport_name->>'en' AS departure_airport,
#     dep.city->>'en' AS departure_city,
#     arr.airport_name->>'en' AS arrival_airport,
#     arr.city->>'en' AS arrival_city
# FROM
#     most_expensive_flights mf
# JOIN flights f ON mf.flight_id = f.flight_id
# JOIN airports_data dep ON f.departure_airport = dep.airport_code
# JOIN airports_data arr ON f.arrival_airport = arr.airport_code;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 1 rows affected.
# [(15328, Decimal('17269600.00'), 'Domodedovo International Airport', 'Moscow', 'Khabarovsk-Novy Airport', 'Khabarovsk')]

# %%
# %%sql
# EXPLAIN ANALYZE
# WITH flight_revenue AS (
#     SELECT
#         flight_id,
#         SUM(amount) AS final_amount
#     FROM ticket_flights
#     GROUP BY flight_id
# ),
# max_revenue AS (
#     SELECT
#         MAX(final_amount) AS max_amount
#     FROM flight_revenue
# ),
# most_expensive_flights AS (
#     SELECT
#         fr.flight_id,
#         fr.final_amount
#     FROM flight_revenue fr
#     JOIN max_revenue mr ON fr.final_amount = mr.max_amount
# )
# SELECT
#     mf.flight_id,
#     mf.final_amount,
#     dep.airport_name->>'en' AS departure_airport,
#     dep.city->>'en' AS departure_city,
#     arr.airport_name->>'en' AS arrival_airport,
#     arr.city->>'en' AS arrival_city
# FROM
#     most_expensive_flights mf
# JOIN flights f ON mf.flight_id = f.flight_id
# JOIN airports_data dep ON f.departure_airport = dep.airport_code
# JOIN airports_data arr ON f.arrival_airport = arr.airport_code;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 43 rows affected.
# [('Hash Join  (cost=397262.55..399372.79 rows=410 width=164) (actual time=4364.956..4396.479 rows=1 loops=1)',),
#  ('  Hash Cond: (f.arrival_airport = arr.airport_code)',),
#  ('  CTE flight_revenue',),
#  ('    ->  Finalize GroupAggregate  (cost=374006.55..395405.61 rows=82036 width=36) (actual time=3887.061..4225.884 rows=150588 loops=1)',),
#  ('          Group Key: ticket_flights.flight_id',),
#  ('          ->  Gather Merge  (cost=374006.55..393149.62 rows=164072 width=36) (actual time=3887.015..3992.985 rows=436915 loops=1)',),
#  ('                Workers Planned: 2',),
#  ('                Workers Launched: 2',),
#  ('                ->  Sort  (cost=373006.53..373211.62 rows=82036 width=36) (actual time=3674.718..3699.213 rows=145638 loops=3)',),
#  ('                      Sort Key: ticket_flights.flight_id',),
#  ('                      Sort Method: external merge  Disk: 10272kB',),
#  ('                      Worker 0:  Sort Method: external merge  Disk: 9992kB',),
#  ('                      Worker 1:  Sort Method: external merge  Disk: 10112kB',),
#  ('                      ->  Partial HashAggregate  (cost=328895.86..364067.26 rows=82036 width=36) (actual time=1688.203..3477.896 rows=145638 loops=3)',),
#  ('                            Group Key: ticket_flights.flight_id',),
#  ('                            Planned Partitions: 8  Batches: 41  Memory Usage: 4305kB  Disk Usage: 96784kB',),
#  ('                            Worker 0:  Batches: 41  Memory Usage: 4305kB  Disk Usage: 74248kB',),
#  ('                            Worker 1:  Batches: 41  Memory Usage: 4305kB  Disk Usage: 80776kB',),
#  ('                            ->  Parallel Seq Scan on ticket_flights  (cost=0.00..104898.45 rows=3496545 width=10) (actual time=0.024..406.200 rows=2797284 loops=3)',),
#  ('  ->  Hash Join  (cost=1851.60..3956.62 rows=410 width=150) (actual time=4346.357..4377.769 rows=1 loops=1)',),
#  ('        Hash Cond: (f.departure_airport = dep.airport_code)',),
#  ('        ->  Nested Loop  (cost=1846.26..3950.16 rows=410 width=44) (actual time=4346.271..4377.681 rows=1 loops=1)',),
#  ('              ->  Hash Join  (cost=1845.84..3706.47 rows=410 width=36) (actual time=4346.233..4377.640 rows=1 loops=1)',),
#  ('                    Hash Cond: (fr.final_amount = (max(flight_revenue.final_amount)))',),
#  ('                    ->  CTE Scan on flight_revenue fr  (cost=0.00..1640.72 rows=82036 width=36) (actual time=3887.066..3900.632 rows=150588 loops=1)',),
#  ('                    ->  Hash  (cost=1845.83..1845.83 rows=1 width=32) (actual time=456.588..456.590 rows=1 loops=1)',),
#  ('                          Buckets: 1024  Batches: 1  Memory Usage: 9kB',),
#  ('                          ->  Aggregate  (cost=1845.81..1845.82 rows=1 width=32) (actual time=456.581..456.582 rows=1 loops=1)',),
#  ('                                ->  CTE Scan on flight_revenue  (cost=0.00..1640.72 rows=82036 width=32) (actual time=0.001..433.159 rows=150588 loops=1)',),
#  ('              ->  Index Scan using flights_pkey on flights f  (cost=0.42..0.59 rows=1 width=12) (actual time=0.029..0.029 rows=1 loops=1)',),
#  ('                    Index Cond: (flight_id = fr.flight_id)',),
#  ('        ->  Hash  (cost=4.04..4.04 rows=104 width=114) (actual time=0.067..0.068 rows=104 loops=1)',),
#  ('              Buckets: 1024  Batches: 1  Memory Usage: 23kB',),
#  ('              ->  Seq Scan on airports_data dep  (cost=0.00..4.04 rows=104 width=114) (actual time=0.011..0.030 rows=104 loops=1)',),
#  ('  ->  Hash  (cost=4.04..4.04 rows=104 width=114) (actual time=18.584..18.585 rows=104 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 23kB',),
#  ('        ->  Seq Scan on airports_data arr  (cost=0.00..4.04 rows=104 width=114) (actual time=18.503..18.536 rows=104 loops=1)',),
#  ('Planning Time: 0.572 ms',),
#  ('JIT:',),
#  ('  Functions: 68',),
#  ('  Options: Inlining false, Optimization false, Expressions true, Deforming true',),
#  ('  Timing: Generation 19.187 ms, Inlining 0.000 ms, Optimization 3.041 ms, Emission 38.864 ms, Total 61.092 ms',),
#  ('Execution Time: 4415.971 ms',)]

# %% [markdown]
# ## Дополнительное задание:
#
# Реализуйте 3 запроса, которые позволят узнать, выявить узкие места работы авиаперевозчика.

# %% [raw]
# Анализ прибыльности рейса

# %%
# %%sql
# WITH flight_revenue AS (
#     SELECT
#         f.flight_id,
#         f.flight_no,
#         f.departure_airport,
#         f.arrival_airport,
#         COUNT(tf.ticket_no) AS tickets_sold,
#         SUM(tf.amount) AS total_revenue,
#         a.model->>'en' AS aircraft_model,
#         a.range
#     FROM
#         flights f
#     JOIN
#         ticket_flights tf ON f.flight_id = tf.flight_id
#     JOIN
#         aircrafts_data a ON f.aircraft_code = a.aircraft_code
#     GROUP BY
#         f.flight_id, f.flight_no, f.departure_airport, f.arrival_airport, a.model, a.range
# )
# SELECT
#     flight_no,
#     departure_airport,
#     arrival_airport,
#     aircraft_model,
#     range,
#     tickets_sold,
#     total_revenue,
#     total_revenue / tickets_sold AS avg_revenue_per_ticket,
#     CASE
#         WHEN total_revenue < 1000000 THEN 'Low Profit'
#         WHEN total_revenue BETWEEN 1000000 AND 3000000 THEN 'Medium Profit'
#         ELSE 'High Profit'
#     END AS profitability
# FROM
#     flight_revenue
# ORDER BY
#     total_revenue DESC
# LIMIT 100;
# Out:
#  * postgresql://reader:***@10.129.0.25/demo
# 100 rows affected.
# [('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 220, Decimal('17269600.00'), Decimal('78498.181818181818'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 219, Decimal('17208100.00'), Decimal('78575.799086757991'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 219, Decimal('17208100.00'), Decimal('78575.799086757991'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 219, Decimal('17208100.00'), Decimal('78575.799086757991'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 219, Decimal('17201900.00'), Decimal('78547.488584474886'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17146600.00'), Decimal('78654.128440366972'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17146600.00'), Decimal('78654.128440366972'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17146600.00'), Decimal('78654.128440366972'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17146600.00'), Decimal('78654.128440366972'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('17085100.00'), Decimal('78733.179723502304'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 218, Decimal('17023600.00'), Decimal('78089.908256880734'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('17023600.00'), Decimal('78812.962962962963'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 218, Decimal('17023600.00'), Decimal('78089.908256880734'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17023600.00'), Decimal('78089.908256880734'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('17023600.00'), Decimal('78812.962962962963'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('17017400.00'), Decimal('78061.467889908257'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16962100.00'), Decimal('78893.488372093023'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16962100.00'), Decimal('78893.488372093023'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 215, Decimal('16962100.00'), Decimal('78893.488372093023'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 217, Decimal('16962100.00'), Decimal('78166.359447004608'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16962100.00'), Decimal('78893.488372093023'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 215, Decimal('16962100.00'), Decimal('78893.488372093023'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16955900.00'), Decimal('78864.651162790698'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16955900.00'), Decimal('78864.651162790698'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16900600.00'), Decimal('78243.518518518519'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16900600.00'), Decimal('78974.766355140187'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16894400.00'), Decimal('78214.814814814815'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16894400.00'), Decimal('78945.794392523364'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16894400.00'), Decimal('78945.794392523364'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 218, Decimal('16894400.00'), Decimal('77497.247706422018'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16839100.00'), Decimal('78321.395348837209'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 213, Decimal('16839100.00'), Decimal('79056.807511737089'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 215, Decimal('16839100.00'), Decimal('78321.395348837209'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16839100.00'), Decimal('79056.807511737089'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16839100.00'), Decimal('78321.395348837209'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16839100.00'), Decimal('79056.807511737089'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 215, Decimal('16839100.00'), Decimal('78321.395348837209'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 215, Decimal('16839100.00'), Decimal('78321.395348837209'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 213, Decimal('16839100.00'), Decimal('79056.807511737089'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 213, Decimal('16839100.00'), Decimal('79056.807511737089'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16832900.00'), Decimal('78292.558139534884'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16832900.00'), Decimal('79027.699530516432'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16832900.00'), Decimal('79027.699530516432'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16777600.00'), Decimal('77674.074074074074'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16777600.00'), Decimal('77674.074074074074'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16777600.00'), Decimal('77674.074074074074'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16777600.00'), Decimal('77674.074074074074'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16777600.00'), Decimal('78400.000000000000'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 212, Decimal('16777600.00'), Decimal('79139.622641509434'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16777600.00'), Decimal('77674.074074074074'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16771400.00'), Decimal('78371.028037383178'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 214, Decimal('16771400.00'), Decimal('78371.028037383178'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 212, Decimal('16771400.00'), Decimal('79110.377358490566'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 214, Decimal('16771400.00'), Decimal('78371.028037383178'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 212, Decimal('16771400.00'), Decimal('79110.377358490566'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 216, Decimal('16765200.00'), Decimal('77616.666666666667'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 211, Decimal('16716100.00'), Decimal('79223.222748815166'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 211, Decimal('16716100.00'), Decimal('79223.222748815166'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 213, Decimal('16716100.00'), Decimal('78479.342723004695'), 'High Profit'),
#  ('PG0209', 'KHV', 'DME', 'Boeing 767-300', 7900, 211, Decimal('16716100.00'), Decimal('79223.222748815166'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 211, Decimal('16716100.00'), Decimal('79223.222748815166'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16716100.00'), Decimal('77749.302325581395'), 'High Profit'),
#  ('PG0208', 'DME', 'KHV', 'Boeing 767-300', 7900, 215, Decimal('16716100.00'), Decimal('77749.302325581395'), 'High Profit')]

# %% [markdown]
# #Самые загруженные аэропорты (10 шт)

# %%
# %%sql
# WITH airport_activity AS (
#     SELECT
#         a.airport_code,
#         a.airport_name->>'en' AS airport_name,
#         a.city->>'en' AS city,
#         COUNT(DISTINCT f.flight_id) AS total_flights,
#         COUNT(tf.ticket_no) AS total_passengers
#     FROM  airports_data a
#     LEFT JOIN
#         flights f ON a.airport_code = f.departure_airport OR a.airport_code = f.arrival_airport
#     LEFT JOIN
#         ticket_flights tf ON f.flight_id = tf.flight_id
#     GROUP BY
#         a.airport_code, a.airport_name, a.city
# )
# SELECT *
# LIMIT 10

# %%
       

SELECT 
    airport_code,
    airport_name,
    city,
    total_flights,
    total_passengers,
    ROUND(total_passengers * 100.0 / (SELECT SUM(total_passengers) FROM airport_activity), 2) AS passenger_share_percent
FROM 
    airport_activity
ORDER BY 
    total_flights DESC, total_passengers DESC
LIMIT 10;
